# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
import torch.utils.data as data

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    transform = transforms.Compose([
     transforms.Resize(image_size),
     transforms.ToTensor(),
    ])
    # TODO: Implement function and return a dataloader
    data_train = datasets.ImageFolder('./data/processed_celeba_small', transform=transform)
    loader =  data.DataLoader(data_train, batch_size=batch_size, shuffle=True)
    
    return loader

# %%
def test_loader():
    loader = iter(get_dataloader(1, (32,32)))
    target, _ = loader.next()
    
    assert len(target) == 1
    assert target[0].shape == torch.Size([3, 32, 32])
    
    loader = iter(get_dataloader(128, (32,2)))
    target, _ = loader.next()
    
    assert len(target) == 128
    assert target[0].shape == torch.Size([3, 32, 2])

    
test_loader()

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = (32,32)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    
    min, max = feature_range
    
    
    return x * (max-min) + min

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9686)
# Max:  tensor(0.8745)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(input_channels, output_channels, kernel_size, batch_norm=True):
    """
    Helper to create convolutional layer with optional batch norm
    :param input_channels: number of channel in input
    :param output_channel: number of channel for output
    :param kernel_size: size of kernel
    :param batch_norm: Should add batch_normalization step
    """
    # Convolutional layer remove bias when batch norm is activated)
    conv_layer = nn.Conv2d(input_channels, output_channels, kernel_size, stride=2, padding=1, bias=(not batch_norm))
    layers = [conv_layer]
    
    # Add batch norm if required
    if batch_norm:
        batch_norm = nn.BatchNorm2d(output_channels)
        layers.append(batch_norm)
        
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim, dropout=0):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        
        self.conv_dim = conv_dim

        # complete init function
        # First convolutional layer take image in input (32x32) => (16x16)
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False)
        # Second convolutional layer take image in input (16x16) => (8x8)
        self.conv2 = conv(conv_dim, conv_dim*2, 4, batch_norm=True)
        # Third convolutional layer take image in input (8x8) => (4x4)
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4, batch_norm=True)
        
        # fully connected layers take vector input 4*4*4* conv_dim and return vector size conv_dim
        self.fc1 = nn.Linear(4*4*4*conv_dim, conv_dim)
        self.fc2 = nn.Linear(conv_dim, 1)
        self.leaky = nn.LeakyReLU(0.02)
        

        self.dropout = nn.Dropout(dropout)

        
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        batch_size = x.shape[0]
        
        x = self.leaky(self.conv1(x))
        x = self.dropout(x)
        x = self.leaky(self.conv2(x))
        x = self.dropout(x)
        x = self.leaky(self.conv3(x))
        x = self.dropout(x)
        
        x = x.view(batch_size, -1)
        
        x = self.leaky(self.fc1(x))
        x = self.dropout(x)
        # Handle sigmoid in loss function ?
        x = F.sigmoid(self.fc2(x))
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(input_channels, output_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    deconv = nn.ConvTranspose2d(input_channels, output_channels, kernel_size, stride,  padding=padding, bias=(not batch_norm))
    
    layers = [deconv]
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(output_channels))
    
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim, dropout=0):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        
        self.conv_dim = conv_dim
        
        self.fc1 = nn.Linear(z_size, 4*4*4*conv_dim)

        # complete init function
        self.deconv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.deconv2 = deconv(conv_dim*2, conv_dim, 4)
        self.deconv3 = deconv(conv_dim, 3 , 4, batch_norm=False)
        self.leaky = nn.LeakyReLU(0.02)
        self.dropout = nn.Dropout(dropout)
        
        #input_channels, output_channels, kernel_size, stride=2, padding=1, bias=(not batch_norm)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        
        x = self.fc1(x)
        x = self.dropout(x)
        
        x = x.view(-1, 4*self.conv_dim, 4,4)
        
        x = self.leaky(self.deconv1(x))
        x = self.dropout(x)
        x = self.leaky(self.deconv2(x))
        x = self.dropout(x)
        x = F.tanh(self.deconv3(x))
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %% [markdown]
# ## /!\ Check this not sure about implementation.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname in ['Conv2d', 'Linear', 'ConvTranspose2d']:
        nn.init.normal_(m.weight, mean=0.0, std=0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim, dropout=0.3)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim, dropout=0.3)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 128

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=4096, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=1, bias=True)
#   (leaky): LeakyReLU(negative_slope=0.02)
#   (dropout): Dropout(p=0.3)
# )
#
# Generator(
#   (fc1): Linear(in_features=128, out_features=4096, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
#   (leaky): LeakyReLU(negative_slope=0.02)
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
# Implementation least square
def real_loss(D_out, smooth=True):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    threshold = 0.9 if smooth else 1
    loss =   torch.mean((D_out-threshold)**2)
    
    #loss = torch.mean((D_out - 1)**2)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    loss = torch.mean(D_out**2)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0001 
b1 = 0.5
b2 = 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr=lr, betas=(b1, b2))
g_optimizer = optim.Adam(G.parameters(), lr=lr, betas=(b1, b2))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size= 16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            
            if train_on_gpu:
                real_images = real_images.cuda()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            
            d_optimizer.zero_grad()
            # Compute loss against fake photos
            random_z = np.random.uniform(-1,1, size=(batch_size, z_size))
            if train_on_gpu:
                random_z = torch.from_numpy(random_z).cuda()
            
            fake_images = G(random_z.float())
            fake_d_loss = fake_loss(D(fake_images))
                                    
            # Compute loss againts real photos
            real_d_loss = real_loss(D(real_images))
            
            d_loss = real_d_loss + fake_d_loss
                                    
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            # Compute loss against generator
            g_optimizer.zero_grad()

            random_z = np.random.uniform(-1,1, size=(batch_size, z_size))
            
            if train_on_gpu:
                random_z = torch.from_numpy(random_z).cuda() 
            
            fake_images = G(random_z.float())
            fake_g_loss = real_loss(D(fake_images))

            # Compute loss against  
            
            g_loss = fake_g_loss
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        #_ = view_samples(0, [samples_z])
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs, print_every=500)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch [    1/   50] | d_loss: 0.4058 | g_loss: 0.1719
# Epoch [    1/   50] | d_loss: 0.2041 | g_loss: 0.4866
# Epoch [    1/   50] | d_loss: 0.2190 | g_loss: 0.3349
# Epoch [    1/   50] | d_loss: 0.3180 | g_loss: 0.4299
# Epoch [    1/   50] | d_loss: 0.2221 | g_loss: 0.4928
# Epoch [    1/   50] | d_loss: 0.1737 | g_loss: 0.6239
# Epoch [    2/   50] | d_loss: 0.2240 | g_loss: 0.4357
# Epoch [    2/   50] | d_loss: 0.2153 | g_loss: 0.5332
# Epoch [    2/   50] | d_loss: 0.2628 | g_loss: 0.4796
# Epoch [    2/   50] | d_loss: 0.3100 | g_loss: 0.4691
# Epoch [    2/   50] | d_loss: 0.2204 | g_loss: 0.5120
# Epoch [    2/   50] | d_loss: 0.1977 | g_loss: 0.6298
# Epoch [    3/   50] | d_loss: 0.2133 | g_loss: 0.4908
# Epoch [    3/   50] | d_loss: 0.1139 | g_loss: 0.6326
# Epoch [    3/   50] | d_loss: 0.0548 | g_loss: 0.5317
# Epoch [    3/   50] | d_loss: 0.0592 | g_loss: 0.6646
# Epoch [    3/   50] | d_loss: 0.1527 | g_loss: 0.6819
# Epoch [    3/   50] | d_loss: 0.2017 | g_loss: 0.3959
# Epoch [    4/   50] | d_loss: 0.2375 | g_loss: 0.6567
# Epoch [    5/   50] | d_loss: 0.1014 | g_loss: 0.6311
# Epoch [    5/   50] | d_loss: 0.1131 | g_loss: 0.6755
# Epoch [    5/   50] | d_loss: 0.0635 | g_loss: 0.5808
# Epoch [    5/   50] | d_loss: 0.1112 | g_loss: 0.5920
# Epoch [    6/   50] | d_loss: 0.1211 | g_loss: 0.5970
# Epoch [    6/   50] | d_loss: 0.0918 | g_loss: 0.6083
# Epoch [    6/   50] | d_loss: 0.0694 | g_loss: 0.5759
# Epoch [    6/   50] | d_loss: 0.1071 | g_loss: 0.6335
# Epoch [    6/   50] | d_loss: 0.0735 | g_loss: 0.5337
# Epoch [    6/   50] | d_loss: 0.0910 | g_loss: 0.6458
# Epoch [    7/   50] | d_loss: 0.0491 | g_loss: 0.7435
# Epoch [    7/   50] | d_loss: 0.2289 | g_loss: 0.3886
# Epoch [    7/   50] | d_loss: 0.0561 | g_loss: 0.4996
# Epoch [    7/   50] | d_loss: 0.1060 | g_loss: 0.7200
# Epoch [    7/   50] | d_loss: 0.0473 | g_loss: 0.5268
# Epoch [    7/   50] | d_loss: 0.0318 | g_loss: 0.5833
# Epoch [    8/   50] | d_loss: 0.1127 | g_loss: 0.7371
# Epoch [    8/   50] | d_loss: 0.0550 | g_loss: 0.6849
# Epoch [    8/   50] | d_loss: 0.0848 | g_loss: 0.5495
# Epoch [    8/   50] | d_loss: 0.1382 | g_loss: 0.7393
# Epoch [    8/   50] | d_loss: 0.1374 | g_loss: 0.6261
# Epoch [    8/   50] | d_loss: 0.0654 | g_loss: 0.6139
# Epoch [    9/   50] | d_loss: 0.0787 | g_loss: 0.6282
# Epoch [    9/   50] | d_loss: 0.1012 | g_loss: 0.7251
# Epoch [    9/   50] | d_loss: 0.1328 | g_loss: 0.6609
# Epoch [    9/   50] | d_loss: 0.0109 | g_loss: 0.7891
# Epoch [    9/   50] | d_loss: 0.0785 | g_loss: 0.7680
# Epoch [    9/   50] | d_loss: 0.1230 | g_loss: 0.7919
# Epoch [   10/   50] | d_loss: 0.1309 | g_loss: 0.4861
# Epoch [   10/   50] | d_loss: 0.0662 | g_loss: 0.7026
# Epoch [   10/   50] | d_loss: 0.1391 | g_loss: 0.7320
# Epoch [   10/   50] | d_loss: 0.0697 | g_loss: 0.7994
# Epoch [   10/   50] | d_loss: 0.0355 | g_loss: 0.6658
# Epoch [   10/   50] | d_loss: 0.0198 | g_loss: 0.4748
# Epoch [   11/   50] | d_loss: 0.0848 | g_loss: 0.3915
# Epoch [   11/   50] | d_loss: 0.0057 | g_loss: 0.7721
# Epoch [   11/   50] | d_loss: 0.0147 | g_loss: 0.5990
# Epoch [   11/   50] | d_loss: 0.0146 | g_loss: 0.7261
# Epoch [   11/   50] | d_loss: 0.0875 | g_loss: 0.7961
# Epoch [   11/   50] | d_loss: 0.0107 | g_loss: 0.7329
# Epoch [   12/   50] | d_loss: 0.1183 | g_loss: 0.7865
# Epoch [   12/   50] | d_loss: 0.0158 | g_loss: 0.7167
# Epoch [   12/   50] | d_loss: 0.0369 | g_loss: 0.7343
# Epoch [   12/   50] | d_loss: 0.1231 | g_loss: 0.5117
# Epoch [   12/   50] | d_loss: 0.0722 | g_loss: 0.5351
# Epoch [   12/   50] | d_loss: 0.0596 | g_loss: 0.6969
# Epoch [   13/   50] | d_loss: 0.0332 | g_loss: 0.8039
# Epoch [   13/   50] | d_loss: 0.1120 | g_loss: 0.7146
# Epoch [   13/   50] | d_loss: 0.0740 | g_loss: 0.7474
# Epoch [   13/   50] | d_loss: 0.0038 | g_loss: 0.7683
# Epoch [   13/   50] | d_loss: 0.0397 | g_loss: 0.6953
# Epoch [   13/   50] | d_loss: 0.0068 | g_loss: 0.7951
# Epoch [   14/   50] | d_loss: 0.0339 | g_loss: 0.7114
# Epoch [   14/   50] | d_loss: 0.0571 | g_loss: 0.8016
# Epoch [   14/   50] | d_loss: 0.0129 | g_loss: 0.7833
# Epoch [   14/   50] | d_loss: 0.0526 | g_loss: 0.7144
# Epoch [   14/   50] | d_loss: 0.0302 | g_loss: 0.7914
# Epoch [   14/   50] | d_loss: 0.0211 | g_loss: 0.7949
# Epoch [   15/   50] | d_loss: 0.0883 | g_loss: 0.7744
# Epoch [   15/   50] | d_loss: 0.0809 | g_loss: 0.7421
# Epoch [   15/   50] | d_loss: 0.0275 | g_loss: 0.7697
# Epoch [   15/   50] | d_loss: 0.0731 | g_loss: 0.7640
# Epoch [   15/   50] | d_loss: 0.0105 | g_loss: 0.7820
# Epoch [   15/   50] | d_loss: 0.0381 | g_loss: 0.6916
# Epoch [   16/   50] | d_loss: 0.0439 | g_loss: 0.7597
# Epoch [   16/   50] | d_loss: 0.0073 | g_loss: 0.8023
# Epoch [   16/   50] | d_loss: 0.0201 | g_loss: 0.7903
# Epoch [   16/   50] | d_loss: 0.0282 | g_loss: 0.8089
# Epoch [   16/   50] | d_loss: 0.0637 | g_loss: 0.7905
# Epoch [   16/   50] | d_loss: 0.0070 | g_loss: 0.7367
# Epoch [   17/   50] | d_loss: 0.0191 | g_loss: 0.4785
# Epoch [   17/   50] | d_loss: 0.1723 | g_loss: 0.7712
# Epoch [   17/   50] | d_loss: 0.0378 | g_loss: 0.5119
# Epoch [   17/   50] | d_loss: 0.0942 | g_loss: 0.7110
# Epoch [   17/   50] | d_loss: 0.0595 | g_loss: 0.7413
# Epoch [   17/   50] | d_loss: 0.0380 | g_loss: 0.8004
# Epoch [   18/   50] | d_loss: 0.2699 | g_loss: 0.7935
# Epoch [   18/   50] | d_loss: 0.0189 | g_loss: 0.8078
# Epoch [   18/   50] | d_loss: 0.0150 | g_loss: 0.7964
# Epoch [   18/   50] | d_loss: 0.0076 | g_loss: 0.7555
# Epoch [   18/   50] | d_loss: 0.0116 | g_loss: 0.7564
# Epoch [   18/   50] | d_loss: 0.0034 | g_loss: 0.8076
# Epoch [   19/   50] | d_loss: 0.0190 | g_loss: 0.7744
# Epoch [   19/   50] | d_loss: 0.0151 | g_loss: 0.8037
# Epoch [   19/   50] | d_loss: 0.0199 | g_loss: 0.4608
# Epoch [   19/   50] | d_loss: 0.0143 | g_loss: 0.8058
# Epoch [   19/   50] | d_loss: 0.0145 | g_loss: 0.7952
# Epoch [   19/   50] | d_loss: 0.0184 | g_loss: 0.7629
# Epoch [   20/   50] | d_loss: 0.0033 | g_loss: 0.7984
# Epoch [   20/   50] | d_loss: 0.0066 | g_loss: 0.7578
# Epoch [   20/   50] | d_loss: 0.0035 | g_loss: 0.7855
# Epoch [   20/   50] | d_loss: 0.5521 | g_loss: 0.5817
# Epoch [   20/   50] | d_loss: 0.0154 | g_loss: 0.7987
# Epoch [   20/   50] | d_loss: 0.0259 | g_loss: 0.7988
# Epoch [   21/   50] | d_loss: 0.0043 | g_loss: 0.7264
# Epoch [   21/   50] | d_loss: 0.0243 | g_loss: 0.7974
# Epoch [   21/   50] | d_loss: 0.0042 | g_loss: 0.8069
# Epoch [   21/   50] | d_loss: 0.1250 | g_loss: 0.7756
# Epoch [   21/   50] | d_loss: 0.0178 | g_loss: 0.8100
# Epoch [   21/   50] | d_loss: 0.0050 | g_loss: 0.8016
# Epoch [   22/   50] | d_loss: 0.0034 | g_loss: 0.7960
# Epoch [   22/   50] | d_loss: 0.3532 | g_loss: 0.6039
# Epoch [   22/   50] | d_loss: 0.0024 | g_loss: 0.8096
# Epoch [   22/   50] | d_loss: 0.0022 | g_loss: 0.8077
# Epoch [   22/   50] | d_loss: 0.0340 | g_loss: 0.8056
# Epoch [   22/   50] | d_loss: 0.0031 | g_loss: 0.8067
# Epoch [   23/   50] | d_loss: 0.0038 | g_loss: 0.7986
# Epoch [   23/   50] | d_loss: 0.0150 | g_loss: 0.8010
# Epoch [   23/   50] | d_loss: 0.0310 | g_loss: 0.7846
# Epoch [   23/   50] | d_loss: 0.1031 | g_loss: 0.7797
# Epoch [   23/   50] | d_loss: 0.0757 | g_loss: 0.6769
# Epoch [   23/   50] | d_loss: 0.0162 | g_loss: 0.8039
# Epoch [   24/   50] | d_loss: 0.0111 | g_loss: 0.7651
# Epoch [   24/   50] | d_loss: 0.0025 | g_loss: 0.7955
# Epoch [   24/   50] | d_loss: 0.0031 | g_loss: 0.8096
# Epoch [   24/   50] | d_loss: 0.0116 | g_loss: 0.7185
# Epoch [   24/   50] | d_loss: 0.0021 | g_loss: 0.7958
# Epoch [   24/   50] | d_loss: 0.0022 | g_loss: 0.8100
# Epoch [   25/   50] | d_loss: 0.0608 | g_loss: 0.8050
# Epoch [   25/   50] | d_loss: 0.0048 | g_loss: 0.7092
# Epoch [   25/   50] | d_loss: 0.0419 | g_loss: 0.7426
# Epoch [   25/   50] | d_loss: 0.0248 | g_loss: 0.8008
# Epoch [   25/   50] | d_loss: 0.0022 | g_loss: 0.7536
# Epoch [   25/   50] | d_loss: 0.0185 | g_loss: 0.8100
# Epoch [   26/   50] | d_loss: 0.0920 | g_loss: 0.7869
# Epoch [   26/   50] | d_loss: 0.3131 | g_loss: 0.8099
# Epoch [   26/   50] | d_loss: 0.0121 | g_loss: 0.8081
# Epoch [   26/   50] | d_loss: 0.0131 | g_loss: 0.7782
# Epoch [   26/   50] | d_loss: 0.0032 | g_loss: 0.8099
# Epoch [   26/   50] | d_loss: 0.0018 | g_loss: 0.8099
# Epoch [   27/   50] | d_loss: 0.0115 | g_loss: 0.7732
# Epoch [   27/   50] | d_loss: 0.0032 | g_loss: 0.7538
# Epoch [   27/   50] | d_loss: 0.0216 | g_loss: 0.8032
# Epoch [   27/   50] | d_loss: 0.0015 | g_loss: 0.7816
# Epoch [   27/   50] | d_loss: 0.0024 | g_loss: 0.8100
# Epoch [   27/   50] | d_loss: 0.0019 | g_loss: 0.7284
# Epoch [   28/   50] | d_loss: 0.0934 | g_loss: 0.8100
# Epoch [   28/   50] | d_loss: 0.0019 | g_loss: 0.8049
# Epoch [   28/   50] | d_loss: 0.0022 | g_loss: 0.8090
# Epoch [   28/   50] | d_loss: 0.0096 | g_loss: 0.6741
# Epoch [   28/   50] | d_loss: 0.0018 | g_loss: 0.8061
# Epoch [   28/   50] | d_loss: 0.0015 | g_loss: 0.8094
# Epoch [   29/   50] | d_loss: 0.0062 | g_loss: 0.7963
# Epoch [   29/   50] | d_loss: 0.0034 | g_loss: 0.8091
# Epoch [   29/   50] | d_loss: 0.0020 | g_loss: 0.7887
# Epoch [   29/   50] | d_loss: 0.0429 | g_loss: 0.8010
# Epoch [   29/   50] | d_loss: 0.0316 | g_loss: 0.8094
# Epoch [   29/   50] | d_loss: 0.0532 | g_loss: 0.8040
# Epoch [   30/   50] | d_loss: 0.0011 | g_loss: 0.8098
# Epoch [   30/   50] | d_loss: 0.0261 | g_loss: 0.8091
# Epoch [   30/   50] | d_loss: 0.0016 | g_loss: 0.8053
# Epoch [   30/   50] | d_loss: 0.1326 | g_loss: 0.6517
# Epoch [   30/   50] | d_loss: 0.0279 | g_loss: 0.8098
# Epoch [   30/   50] | d_loss: 0.0321 | g_loss: 0.8043
# Epoch [   31/   50] | d_loss: 0.0020 | g_loss: 0.8092
# Epoch [   31/   50] | d_loss: 0.0019 | g_loss: 0.8012
# Epoch [   31/   50] | d_loss: 0.0031 | g_loss: 0.7952
# Epoch [   31/   50] | d_loss: 0.0328 | g_loss: 0.7839
# Epoch [   31/   50] | d_loss: 0.0018 | g_loss: 0.7950
# Epoch [   31/   50] | d_loss: 0.0106 | g_loss: 0.7924
# Epoch [   32/   50] | d_loss: 0.0014 | g_loss: 0.8052
# Epoch [   32/   50] | d_loss: 0.0148 | g_loss: 0.7992
# Epoch [   32/   50] | d_loss: 0.0197 | g_loss: 0.7374
# Epoch [   32/   50] | d_loss: 0.0015 | g_loss: 0.7952
# Epoch [   32/   50] | d_loss: 0.0011 | g_loss: 0.8099
# Epoch [   32/   50] | d_loss: 0.0066 | g_loss: 0.8088
# Epoch [   33/   50] | d_loss: 0.0010 | g_loss: 0.8075
# Epoch [   33/   50] | d_loss: 0.0047 | g_loss: 0.8100
# Epoch [   33/   50] | d_loss: 0.0037 | g_loss: 0.8099
# Epoch [   33/   50] | d_loss: 0.0093 | g_loss: 0.7552
# Epoch [   33/   50] | d_loss: 0.0019 | g_loss: 0.7988
# Epoch [   33/   50] | d_loss: 0.0021 | g_loss: 0.7837
# Epoch [   34/   50] | d_loss: 0.0017 | g_loss: 0.7913
# Epoch [   34/   50] | d_loss: 0.0007 | g_loss: 0.8055
# Epoch [   34/   50] | d_loss: 0.0061 | g_loss: 0.7928
# Epoch [   34/   50] | d_loss: 0.0703 | g_loss: 0.5678
# Epoch [   34/   50] | d_loss: 0.0269 | g_loss: 0.7726
# Epoch [   34/   50] | d_loss: 0.0063 | g_loss: 0.7392
# Epoch [   35/   50] | d_loss: 0.0011 | g_loss: 0.7754
# Epoch [   35/   50] | d_loss: 0.0074 | g_loss: 0.8091
# Epoch [   35/   50] | d_loss: 0.0146 | g_loss: 0.8099
# Epoch [   35/   50] | d_loss: 0.0034 | g_loss: 0.8089
# Epoch [   35/   50] | d_loss: 0.0007 | g_loss: 0.7415
# Epoch [   35/   50] | d_loss: 0.0044 | g_loss: 0.8090
# Epoch [   36/   50] | d_loss: 0.0369 | g_loss: 0.7844
# Epoch [   36/   50] | d_loss: 0.0322 | g_loss: 0.8020
# Epoch [   36/   50] | d_loss: 0.0043 | g_loss: 0.8096
# Epoch [   36/   50] | d_loss: 0.0063 | g_loss: 0.7863
# Epoch [   36/   50] | d_loss: 0.0009 | g_loss: 0.7911
# Epoch [   36/   50] | d_loss: 0.0250 | g_loss: 0.7918
# Epoch [   37/   50] | d_loss: 0.0012 | g_loss: 0.7981
# Epoch [   37/   50] | d_loss: 0.0012 | g_loss: 0.8070
# Epoch [   37/   50] | d_loss: 0.0013 | g_loss: 0.8058
# Epoch [   37/   50] | d_loss: 0.0124 | g_loss: 0.8098
# Epoch [   37/   50] | d_loss: 0.0007 | g_loss: 0.8017
# Epoch [   37/   50] | d_loss: 0.0022 | g_loss: 0.7537
# Epoch [   38/   50] | d_loss: 0.0064 | g_loss: 0.8088
# Epoch [   38/   50] | d_loss: 0.0010 | g_loss: 0.8099
# Epoch [   38/   50] | d_loss: 0.0097 | g_loss: 0.7977
# Epoch [   38/   50] | d_loss: 0.0079 | g_loss: 0.8100
# Epoch [   38/   50] | d_loss: 0.0053 | g_loss: 0.8095
# Epoch [   38/   50] | d_loss: 0.0016 | g_loss: 0.7908
# Epoch [   39/   50] | d_loss: 0.0184 | g_loss: 0.8054
# Epoch [   39/   50] | d_loss: 0.0007 | g_loss: 0.8098
# Epoch [   39/   50] | d_loss: 0.0010 | g_loss: 0.8031
# Epoch [   39/   50] | d_loss: 0.0186 | g_loss: 0.8099
# Epoch [   39/   50] | d_loss: 0.0030 | g_loss: 0.7876
# Epoch [   39/   50] | d_loss: 0.0009 | g_loss: 0.8049
# Epoch [   40/   50] | d_loss: 0.0053 | g_loss: 0.8099
# Epoch [   40/   50] | d_loss: 0.0009 | g_loss: 0.8092
# Epoch [   40/   50] | d_loss: 0.0024 | g_loss: 0.8088
# Epoch [   40/   50] | d_loss: 0.0234 | g_loss: 0.8098
# Epoch [   40/   50] | d_loss: 0.0276 | g_loss: 0.8040
# Epoch [   40/   50] | d_loss: 0.0024 | g_loss: 0.8029
# Epoch [   41/   50] | d_loss: 0.0012 | g_loss: 0.8044
# Epoch [   41/   50] | d_loss: 0.0015 | g_loss: 0.8010
# Epoch [   41/   50] | d_loss: 0.0824 | g_loss: 0.8037
# Epoch [   41/   50] | d_loss: 0.0008 | g_loss: 0.8100
# Epoch [   41/   50] | d_loss: 0.0084 | g_loss: 0.7831
# Epoch [   41/   50] | d_loss: 0.0121 | g_loss: 0.7951
# Epoch [   42/   50] | d_loss: 0.0035 | g_loss: 0.8053
# Epoch [   42/   50] | d_loss: 0.0009 | g_loss: 0.8100
# Epoch [   42/   50] | d_loss: 0.0253 | g_loss: 0.8091
# Epoch [   42/   50] | d_loss: 0.0005 | g_loss: 0.8100
# Epoch [   42/   50] | d_loss: 0.0019 | g_loss: 0.8081
# Epoch [   42/   50] | d_loss: 0.0007 | g_loss: 0.8048
# Epoch [   43/   50] | d_loss: 0.0085 | g_loss: 0.8097
# Epoch [   43/   50] | d_loss: 0.0009 | g_loss: 0.8100
# Epoch [   43/   50] | d_loss: 0.0035 | g_loss: 0.8100
# Epoch [   43/   50] | d_loss: 0.0014 | g_loss: 0.8062
# Epoch [   43/   50] | d_loss: 0.0180 | g_loss: 0.8100
# Epoch [   43/   50] | d_loss: 0.0008 | g_loss: 0.7953
# Epoch [   44/   50] | d_loss: 0.0166 | g_loss: 0.7935
# Epoch [   44/   50] | d_loss: 0.0010 | g_loss: 0.8100
# Epoch [   44/   50] | d_loss: 0.0007 | g_loss: 0.7970
# Epoch [   44/   50] | d_loss: 0.0014 | g_loss: 0.8099
# Epoch [   44/   50] | d_loss: 0.1207 | g_loss: 0.7758
# Epoch [   44/   50] | d_loss: 0.0014 | g_loss: 0.8096
# Epoch [   45/   50] | d_loss: 0.0007 | g_loss: 0.8097
# Epoch [   45/   50] | d_loss: 0.0189 | g_loss: 0.8091
# Epoch [   45/   50] | d_loss: 0.0020 | g_loss: 0.8097
# Epoch [   45/   50] | d_loss: 0.0014 | g_loss: 0.8028
# Epoch [   45/   50] | d_loss: 0.0031 | g_loss: 0.7537
# Epoch [   45/   50] | d_loss: 0.0008 | g_loss: 0.8079
# Epoch [   46/   50] | d_loss: 0.0007 | g_loss: 0.8093
# Epoch [   46/   50] | d_loss: 0.0012 | g_loss: 0.8100
# Epoch [   46/   50] | d_loss: 0.0218 | g_loss: 0.8100
# Epoch [   46/   50] | d_loss: 0.0239 | g_loss: 0.8005
# Epoch [   46/   50] | d_loss: 0.0009 | g_loss: 0.8089
# Epoch [   46/   50] | d_loss: 0.0026 | g_loss: 0.8100
# Epoch [   47/   50] | d_loss: 0.0021 | g_loss: 0.7562
# Epoch [   47/   50] | d_loss: 0.0337 | g_loss: 0.8077
# Epoch [   47/   50] | d_loss: 0.0234 | g_loss: 0.8018
# Epoch [   47/   50] | d_loss: 0.0158 | g_loss: 0.8100
# Epoch [   47/   50] | d_loss: 0.0011 | g_loss: 0.8099
# Epoch [   47/   50] | d_loss: 0.0015 | g_loss: 0.8029
# Epoch [   48/   50] | d_loss: 0.0060 | g_loss: 0.8070
# Epoch [   48/   50] | d_loss: 0.0009 | g_loss: 0.8070
# Epoch [   48/   50] | d_loss: 0.0006 | g_loss: 0.8095
# Epoch [   48/   50] | d_loss: 0.0312 | g_loss: 0.8099
# Epoch [   48/   50] | d_loss: 0.0017 | g_loss: 0.8096
# Epoch [   48/   50] | d_loss: 0.0010 | g_loss: 0.7941
# Epoch [   49/   50] | d_loss: 0.0009 | g_loss: 0.8092
# Epoch [   49/   50] | d_loss: 0.0098 | g_loss: 0.8099
# Epoch [   49/   50] | d_loss: 0.0016 | g_loss: 0.8088
# Epoch [   49/   50] | d_loss: 0.0022 | g_loss: 0.7324
# Epoch [   49/   50] | d_loss: 0.0008 | g_loss: 0.8047
# Epoch [   49/   50] | d_loss: 0.0043 | g_loss: 0.7819
# Epoch [   50/   50] | d_loss: 0.0006 | g_loss: 0.8100
# Epoch [   50/   50] | d_loss: 0.0065 | g_loss: 0.8100
# Epoch [   50/   50] | d_loss: 0.0009 | g_loss: 0.8098
# Epoch [   50/   50] | d_loss: 0.0016 | g_loss: 0.7932
# Epoch [   50/   50] | d_loss: 0.0006 | g_loss: 0.8090
# Epoch [   50/   50] | d_loss: 0.0007 | g_loss: 0.7691

# %%
full_losses = losses.copy()

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
def generate_and_display_sample():
    G.eval() # for generating samples
    fixed_z = np.random.uniform(-1, 1, size=(16, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
G.eval() # for generating samples
fixed_z = np.random.uniform(-1, 1, size=(16, z_size))
fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
if train_on_gpu:
    fixed_z = fixed_z.cuda()
samples_z = G(fixed_z)
samples1= []
samples1.append(samples_z)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
_ = view_samples(-1, samples)

# %%
def display_progress(position, samples):
    nrows = len(samples) // 8
    progress = [exemple[position] for exemple in samples]
    fig, axes = plt.subplots(figsize=(16,10), nrows=nrows, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), progress):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
progress = [exemple[1] for exemple in samples]
len(progress)
#len(progress[0])
# Out:
# 20

# %%
display_progress(8, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
#
#
# -----
# # ITERATION #1
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|
# | #1  | 0.002  |    Adam       |   0.5   |    0.999   |      32      |   32         |     16   |    50    |
#
#
#
# ![Try 1](results/try-1.png)
#
#
# First attemps gave results that looked like faces but could not one second confond an human
# Looking at the loss graph it looked like both model were failing to converge.
# I then tried a smaller learning rate
#
# ----
# # ITERATION #2
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|
# | #2  | 0.0002  |    Adam       |   0.5   |    0.999   |      32      |   32         |     16   |   50     |
#
#
# ![Try 2](results/try-2.png)
#
# A smaller learning rate seems to make a better result.
# However I wanted to try if a wider space dimension for the latent vector made better results
#
# ----
# # ITERATION #3
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|
# | #2  | 0.0002  |    Adam       |   0.5   |    0.999   |      64      |   32         |     30   |   20     |
#
#
# ![Try 3](results/try-3.png)
#
# A wider latent vector seems to have some impact and surprisingly it looked like it converged sooner.
# I am not sure why.  But still the results where average. I was convinced that a larger model could work better.
# I then double the generator convolution depth.
#
# ----
# # ITERATION #4
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|
# | #2  | 0.0002  |    Adam       |   0.5   |    0.999   |      64      |   32         |     30   |   20     |
#
#
# ![Try4](results/try-5.png)
#
# A convolution depth seems to make some of better visual results and a smaller generator loss.  With pretty convincing  but still very bad artefacts on some faces.
# I then tryed to increase the discrimitator convolution depth to 64 and increase the number of epoch (since it make sense that a deeper network would be a little slower to converge.
#
# ----
# # ITERATION #5
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|
# | #2  | 0.0002  |    Adam       |   0.5   |    0.999   |      64      |   64        |     30   |   20     |
#
#
# ![Try 5](results/try-6.png)
#
# With deeper discrimitator and generator I have been able to get pretty good results! They are still some artefact that does not seems to disapear after training but most of the generated faces are good and some are really indistinguishable from real picture.
#
#
#
# Obviously all generated faces where white, without hat or glasses wich I assume  describes the majority of the dataset.  Althougth the gender seems to be quite well distributed.
#
# Next step would be to try to generate images in the original size (64x64) in order to see if we could get comparable results.
#
# Also it would be very interesting to create a kind of mapping between the latent vector space and the generated image in order to generate images with specific caracteristics.
# I am officialy assigning this task to my future self!
#
# # ITERATION #6 (Post review)
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch | dropout | batch_size |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|--------|--------|
# | #2  | 0.0002  |    Adam       |   0.5   |    0.999   |      64      |   64        |     30   |   20     |false| 32|
#
# ![Try-6](results/try-7.png)
#
# Try to decrease to batch size from 128  to 32
# There seems to be a little less trash in the sample generated and the loss graph does not looks like it should be.
#
# I try adding dropout.
#
#
# # ITERATION #7 (post review)
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch | dropout | batch_size |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|--------|--------|
# | #2  | 0.0002  |    Adam       |   0.5   |    0.999   |      64      |   64       |     30   |   20     |true| 32|
#
# ![Try 7](results/try-9.png)
#
# Added dropout in both generator
#
#
# # ITERATION #8 Final results
#
# | Try | lr | optimizer | beta | beta2 | g_conv_dim | d_conv_dim | z_size | epoch | dropout | batch_size |
# |-----|----|-----------|------|-------|------------|------------|--------|--------|--------|--------|
# | #2  | 0.0002  |    Adam       |   0.5   |    0.999   |      64      |   64        |     30   |   20     |true| 32|
#
#
#
# ![Try 5](results/try-10.png)
#
# Increasing latent vector size to 128 looked to reduce the trash exemple and some of the

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
